# %% [markdown]
# <a href="https://colab.research.google.com/github/yantitheresia/Data-Mining-2023/blob/main/Klastering_dengan_AHC_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import library
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
import numpy as np
import pandas as pd

# %%
data = pd.read_excel("Data AHC.xlsx")
print(data)
# Out:
#    DTW  DTT  DMT  DDB
# 0    2    4    4    3
# 1    3    4    3    5
# 2    4    3    2    5
# 3    1    5    4    2
# 4    3    2    1    3

# %%
x = np.asarray(data)
print(x)
# Out:
# [[2 4 4 3]
#  [3 4 3 5]
#  [4 3 2 5]
#  [1 5 4 2]
#  [3 2 1 3]]

# %%
#lakukan hierarchical klastering
Z = linkage(x)

# %%
print(Z)
# Out:
# [[0.         3.         1.73205081 2.        ]
#  [1.         2.         1.73205081 2.        ]
#  [5.         6.         2.44948974 4.        ]
#  [4.         7.         2.64575131 5.        ]]

# %%
#plot dendogram
plt.figure(figsize=(25, 10))
plt.title('Dendrogram Hierarchical Klastering')
plt.xlabel('data')
plt.ylabel('jarak')
dendrogram(Z)
plt.show()
