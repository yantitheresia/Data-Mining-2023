# %% [markdown]
# <a href="https://colab.research.google.com/github/yantitheresia/Data-Mining-2023/blob/main/umlah_Penduduk_Menurut_Agama_menggunakan_Asosiasi_dengan_Apriori.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Sumber file => https://satudata.kemenag.go.id/dataset
# Sumber Dataset => https://satudata.kemenag.go.id/dataset/detail/jumlah-penduduk-menurut-agama

# %%
# Langkah 1: Mengimpor library yang diperlukan
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# %%
# Langkah 2: Meload dan Mengeksplor data
# Memuat Data
data = pd.read_excel("Jumlah Penduduk Menurut Agama.xlsx")
data.head()
# Out:
#   Jumlah Penduduk Menurut Agama Unnamed: 1  ... Unnamed: 8 Unnamed: 9
# 0                      Provinsi      Islam  ...     Jumlah      Tahun
# 1                          Aceh    5356635  ...    5432312       2022
# 2                Sumatera Utara   10244655  ...   15372437       2022
# 3                Sumatera Barat    5528423  ...    5664988       2022
# 4                          Riau    5870015  ...    6743099       2022
#
# [5 rows x 10 columns]

# %%
# Mengeksplor kolom data
data.columns
# Out:
# Index(['Jumlah Penduduk Menurut Agama', 'Unnamed: 1', 'Unnamed: 2',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')
